# %%
import cv2
import matplotlib.pyplot as plt

imgpath = []
img = []
titles = []
images = []

imgpath.append("ref/tobey.jpg")
imgpath.append("ref/Kemas Muhammad Irsan Riza.jpg")
img.append(cv2.imread(imgpath[0], 0))
img.append(cv2.imread(imgpath[1], 0))
titles.append(imgpath[0])
titles.append(imgpath[1])
images.append(img[0])
images.append(img[1])

gs = GridSpec(4, 3)

plt.subplot(gs[0,0])
plt.imshow(images[0])
plt.xlabel(titles[0])
plt.xticks([])
plt.yticks([])

plt.subplot(gs[0,2])
plt.imshow(images[1])
plt.xlabel(titles[1])
plt.xticks([])
plt.yticks([])


plt.show()
