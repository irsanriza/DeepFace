# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# # Install Requirement

# %%
# !pip install deepface
from deepface import DeepFace
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
import glob
# Out:
# Collecting deepface
#   Downloading deepface-0.0.75-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.7 MB/s
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from deepface) (2.8.0)
# Collecting retina-face>=0.0.1
#   Downloading retina_face-0.0.10-py3-none-any.whl (15 kB)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from deepface) (1.1.4)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from deepface) (1.3.5)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from deepface) (7.1.2)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.7/dist-packages (from deepface) (4.4.0)
# Collecting fire>=0.4.0
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 7.7 MB/s
# Collecting mtcnn>=0.1.0
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 82.9 MB/s
# Collecting opencv-python>=4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 1.1 MB/s
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from deepface) (2.8.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from deepface) (1.21.6)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.7/dist-packages (from deepface) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire>=0.4.0->deepface) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.1.2->deepface) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->deepface) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->deepface) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->deepface) (4.6.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->deepface) (2022.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (4.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (57.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (3.17.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (0.25.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (1.44.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (14.0.1)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 97.6 MB/s
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (1.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->deepface) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=1.9.0->deepface) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=925d677d31fa774fb561d91f700ce42a89e9c6e5c2bd0482abc2f9c13e0fda31
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# Installing collected packages: tf-estimator-nightly, opencv-python, retina-face, mtcnn, fire, deepface
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed deepface-0.0.75 fire-0.4.0 mtcnn-0.1.1 opencv-python-4.5.5.64 retina-face-0.0.10 tf-estimator-nightly-2.8.0.dev2021122109
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %% [markdown]
# # Load Pas Foto dan Data Uji

# %%
data_folder = '/gdrive/MyDrive/Tugas Deepface/'

#Data Pas Foto
data_pas_foto = os.path.join(data_folder, 'Pas Foto')
list_data_pas_foto = []
for filename in glob.glob(data_pas_foto + '/*.jpg') + glob.glob(data_pas_foto + '/*.jpeg') + glob.glob(data_pas_foto + '/*.png') + glob.glob(data_pas_foto + '/*.jfif'):
    im=Image.open(filename)
    list_data_pas_foto.append(im.filename)


#Data Uji
data_uji = os.path.join(data_folder, 'Tes Data')
assert os.path.isdir(data_uji), print(f'Could not find {data_uji}')
list_data_uji = []
for filename in glob.glob(data_uji + '/*.jpg') + glob.glob(data_uji + '/*.jpeg') + glob.glob(data_uji + '/*.png') + glob.glob(data_uji + '/*.jfif'):
    im=Image.open(filename)
    list_data_uji.append(im.filename)

# %% [markdown]
# # Tampilan Citra Pas Foto (Jumlah data 25)

# %%
plt.figure(figsize=(15,15))
random_inds = np.random.choice(len(list_data_pas_foto),25, replace=False)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(plt.imread(list_data_pas_foto[image_ind])), cmap=plt.cm.binary)
    plt.xlabel(os.path.basename(list_data_pas_foto[image_ind]))

# %% [markdown]
# # Tampilan Data Uji (Jumlah Data 49)

# %%
plt.figure(figsize=(18,18))
random_inds = np.random.choice(len(list_data_uji),49,replace=False)
for i in range(49):
    plt.subplot(7,7,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image_ind = random_inds[i]
    plt.imshow(np.squeeze(plt.imread(list_data_uji[image_ind])), cmap=plt.cm.binary)
    plt.xlabel(os.path.basename(list_data_uji[image_ind]))
    # plt.tight_layout()

# %% [markdown]
# # Deteksi dan Pengenalan Wajah

# %%
# load data uji & dan mencari gambar yang sama pada data  pas Foto 
imgs = []
img_paths = []
results = []
valid_images = [".jpg",".jpeg",".png",".jfif"]

# Detector, Model, dan Metriks yang digunakan
detectors = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']
metrics = ["cosine", "euclidean", "euclidean_l2"]
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
detector =4
metrik = 0
model = 2

for images in os.listdir(data_uji):
  ext = os.path.splitext(images.lower())[1]
  if ext.lower() not in valid_images:
    continue
  print('image = '+images)
  # save img path to array
  img_path = data_uji+"/"+images
  img_paths.append(img_path)

  # save image to array
  img = DeepFace.detectFace(img_path = img_path, detector_backend = detectors[detector], enforce_detection = False, align = True)
  imgs.append(img)

  # face verification
  result = DeepFace.find(img_path = img_path, db_path = data_pas_foto, model_name = models[model],detector_backend = detectors[detector], 
                         distance_metric = metrics[metrik],enforce_detection = False, align = True)

  # save result to array
  results.append(result)

# array length
print('image path array length = '+str(len(np.array(img_paths))))
print('image array length = '+str(len(np.array(imgs))))
print('result array length = '+str(len(np.array(results))))
results[0]
# Out:
# image = arief sartono.jpg
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:06<00:00, 18.1MB/s]
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.46969151496887207  seconds
# image = muhammad khaerul naim.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.23007845878601074  seconds
# image = leni fitriani.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1826634407043457  seconds
# image = dewi tresnawati.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18727493286132812  seconds
# image = hartanto tantriawan.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.17638731002807617  seconds
# image = meredita susanty.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18595480918884277  seconds
# image = meza silvana.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.17064142227172852  seconds
# image = lathifah arief.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1549680233001709  seconds
# image = mohamad idris.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18950557708740234  seconds
# image = mina ismu rahayu.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.6110255718231201  seconds
# image = ahmad Luky Ramdani.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1603865623474121  seconds
# image = handoko supeno.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1593325138092041  seconds
# image = imam ekowicaksono.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.15816903114318848  seconds
# image = riyanto riyanto.jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.22441887855529785  seconds
# image = yaya setiyadi.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18454194068908691  seconds
# image = riza ibnu adam.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.21123027801513672  seconds
# image = ricky isfandiari.jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.2524142265319824  seconds
# image = reza budiawan.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.3420419692993164  seconds
# image = sulthoni ashiddiiqi.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1540226936340332  seconds
# image = rahman indra kesuma.jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1651308536529541  seconds
# image = unknown-(29).png
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.19482016563415527  seconds
# image = unknown-(30).png
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.16411972045898438  seconds
# image = unknown-(31).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.19636988639831543  seconds
# image = unknown-(27).jfif
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.20217466354370117  seconds
# image = unknown-(31).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18709611892700195  seconds
# image = unknown-(27).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.2158823013305664  seconds
# image = unknown-(29).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.2230854034423828  seconds
# image = unknown-(35).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.15868377685546875  seconds
# image = unknown-(38).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.19016122817993164  seconds
# image = unknown-(30).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.19129323959350586  seconds
# image = unknown-(28).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.15928435325622559  seconds
# image = unknown-(33).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.192976713180542  seconds
# image = unknown-(27).png
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.20459604263305664  seconds
# image = unknown-(37).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.21659135818481445  seconds
# image = unknown-(30).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.20612597465515137  seconds
# image = unknown-(28).png
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18469738960266113  seconds
# image = unknown-(39).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.2126448154449463  seconds
# image = unknown-(29).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18616318702697754  seconds
# image = unknown-(34).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.18974089622497559  seconds
# image = unknown-(28).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.2538001537322998  seconds
# image = unknown-(32).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.16238760948181152  seconds
# image = unknown-(36).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.197340726852417  seconds
# image = unknown-(27).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.15785527229309082  seconds
# image = unknown-(32).jpeg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.21716642379760742  seconds
# image = unknown-(33).jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1888871192932129  seconds
# image = varuliantor dear.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.5037801265716553  seconds
# image = kemas muhammad irsan riza.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.16978716850280762  seconds
# image = adiyasa nurfalah.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.1729726791381836  seconds
# image = baud prananto.jpg
# WARNING: Representations for images in  /gdrive/MyDrive/Tugas Deepface/Pas Foto  folder were previously stored in  representations_facenet512.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  23  representations found in  representations_facenet512.pkl
# find function lasts  0.5806539058685303  seconds
# image path array length = 49
# image array length = 49
# result array length = 49
#                                             identity  Facenet512_cosine
# 0  /gdrive/MyDrive/Tugas Deepface/Pas Foto/arief ...           0.211165

# %%
# create side by side for image show
side_imgs = []
side_paths = []
for i in range(len(img_paths)):
  side_imgs.append(imgs[i])
  side_paths.append(img_paths[i])
  res_img_path = "null"
  img = "null"
  if len(np.array(results[i]))>0:
    res_img_path = np.array(results[i])[0][0]
    img = DeepFace.detectFace(img_path = res_img_path, 
                              detector_backend = detectors[detector], enforce_detection = False, align = True)
  side_imgs.append(img)
  side_paths.append(res_img_path)

# %%
# show side by side test-ref
plt.figure(figsize=(15,150))
for i in range(len(img_paths)*2):
    plt.subplot(len(img_paths),2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if side_imgs[i]=="null":
      plt.imshow(np.zeros((100,100,3), np.uint8))
      plt.xlabel("unknown")
    else:
      plt.imshow(np.array(side_imgs[i]))
      plt.xlabel(side_paths[i])
      plt.tight_layout()

# %%
# setting parameter
THRESHOLD = 0.5

# show distance, label, and result
correctness = 0
for i in range(len(img_paths)):
  test_filename = img_paths[i][len(data_uji)+1:]
  arr_test_filename = test_filename.split('-')

  if len(np.array(results[i]))>0:
    res_img_path = np.array(results[i])[0][0]
    ref_filename = res_img_path[len(data_pas_foto)+1:]
    arr_ref_filename = ref_filename.split('-')
    distance = np.array(results[i])[0][1]
  else:
    ref_filename = '-'
    distance = 1000
    arr_ref_filename = '-'
  
  if distance>THRESHOLD:
    label = 'unknown'
  else:
    label = arr_ref_filename[0]
  
  if label == arr_test_filename[0]:
    status = True
    correctness +=1
  else:
    status = False
  
  print('\n'+str(i+1)+
        '. '+test_filename+
        ', '+ref_filename+
        ', '+str(distance)+
        ', '+label+
        ', '+str(status))
# Out:
# 1. arief sartono.jpg, -, 1000, unknown, False
#
# 2. muhammad khaerul naim.jpg, muhammad khaerul naim.jpg, 0.7229118034298979, unknown, False
#
# 3. leni fitriani.jpg, riza ibnu adam.jpg, 0.7270520791261537, unknown, False
#
# 4. dewi tresnawati.jpg, dewi tresnawati.jpg, 0.8662692790776878, unknown, False
#
# 5. hartanto tantriawan.jpg, hartanto tantriawan.jpg, 7.569133155171331e-07, hartanto tantriawan.jpg, True
#
# 6. meredita susanty.jpg, meredita susanty.jpg, 0.6340512175209567, unknown, False
#
# 7. meza silvana.jpg, meza silvana.jpg, 0.42646530235398933, meza silvana.jpg, True
#
# 8. lathifah arief.jpg, lathifah arief.jpg, 0.9436359338246282, unknown, False
#
# 9. mohamad idris.jpg, dewi tresnawati.jpg, 0.9659713380076514, unknown, False
#
# 10. mina ismu rahayu.jpg, mina ismu rahayu.jpg, 0.6621275733392523, unknown, False
#
# 11. ahmad Luky Ramdani.jpg, ahmad Luky Ramdani.jpg, 0.5213338533060106, unknown, False
#
# 12. handoko supeno.jpg, handoko supeno.jpg, 0.8274178844403027, unknown, False
#
# 13. imam ekowicaksono.jpg, imam ekowicaksono.jpg, 0.478919543098842, imam ekowicaksono.jpg, True
#
# 14. riyanto riyanto.jpeg, rahman indra kesuma.jpg, 0.8581305386429746, unknown, False
#
# 15. yaya setiyadi.jpg, yaya setiyadi.jpg, 0.575026967551703, unknown, False
#
# 16. riza ibnu adam.jpg, riza ibnu adam.jpg, 0.5325491659000353, unknown, False
#
# 17. ricky isfandiari.jpeg, sulthoni ashiddiiqi.jpg, 0.8295223110206551, unknown, False
#
# 18. reza budiawan.jpg, reza budiawan.jpg, 0.7367457256495692, unknown, False
#
# 19. sulthoni ashiddiiqi.jpg, riza ibnu adam.jpg, 0.8049093458675137, unknown, False
#
# 20. rahman indra kesuma.jpeg, rahman indra kesuma.jpg, 0.7637823731674008, unknown, False
#
# 21. unknown-(29).png, -, 1000, unknown, True
#
# 22. unknown-(30).png, -, 1000, unknown, True
#
# 23. unknown-(31).jpg, handoko supeno.jpg, 1.0114030761493653, unknown, True
#
# 24. unknown-(27).jfif, ahmad Luky Ramdani.jpg, 0.9261368010105379, unknown, True
#
# 25. unknown-(31).jpeg, dewi tresnawati.jpg, 0.8875774848784356, unknown, True
#
# 26. unknown-(27).jpeg, -, 1000, unknown, True
#
# 27. unknown-(29).jpg, baud prananto.jpg, 0.927523544928244, unknown, True
#
# 28. unknown-(35).jpeg, -, 1000, unknown, True
#
# 29. unknown-(38).jpeg, -, 1000, unknown, True
#
# 30. unknown-(30).jpeg, -, 1000, unknown, True
#
# 31. unknown-(28).jpg, -, 1000, unknown, True
#
# 32. unknown-(33).jpeg, andik wijanarko.jpg, 0.9669231918745356, unknown, True
#
# 33. unknown-(27).png, varuliantor dear.jpg, 0.8027164072849602, unknown, True
#
# 34. unknown-(37).jpeg, riza ibnu adam.jpg, 0.8799967636577584, unknown, True
#
# 35. unknown-(30).jpg, varuliantor dear.jpg, 0.8134765878899051, unknown, True
#
# 36. unknown-(28).png, adiyasa nurfalah.jpg, 0.9341676152935476, unknown, True
#
# 37. unknown-(39).jpeg, -, 1000, unknown, True
#
# 38. unknown-(29).jpeg, handoko supeno.jpg, 0.9270073212223836, unknown, True
#
# 39. unknown-(34).jpeg, -, 1000, unknown, True
#
# 40. unknown-(28).jpeg, -, 1000, unknown, True
#
# 41. unknown-(32).jpg, meredita susanty.jpg, 0.9510992977185858, unknown, True
#
# 42. unknown-(36).jpeg, -, 1000, unknown, True
#
# 43. unknown-(27).jpg, baud prananto.jpg, 1.014915398398798, unknown, True
#
# 44. unknown-(32).jpeg, -, 1000, unknown, True
#
# 45. unknown-(33).jpg, meza silvana.jpg, 1.0270688713179887, unknown, True
#
# 46. varuliantor dear.jpg, varuliantor dear.jpg, 0.5535173357953228, unknown, False
#
# 47. kemas muhammad irsan riza.jpg, kemas muhammad irsan riza.jpg, 0.6806954585949235, unknown, False
#
# 48. adiyasa nurfalah.jpg, adiyasa nurfalah.jpg, 0.6914657709300505, unknown, False
#
# 49. baud prananto.jpg, baud prananto.jpg, 0.594857037219395, unknown, False

# %%
# print accuracy
accuracy = correctness/len(img_paths)*100
print('No. of test data = '+str(len(img_paths)))
print('No. of correct recognition = '+str(correctness))
print('Accuracy = '+str(accuracy)+' %')
# Out:
# No. of test data = 49
# No. of correct recognition = 28
# Accuracy = 57.14285714285714 %
